# %% [markdown]
# <a href="https://colab.research.google.com/github/IlyaOdnodvorets/nn2022/blob/main/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Лабораторна робота №4**
# ##Виконав студент групи КН-31 Однодворець Ілля
#
# ---

# %% [markdown]
# ##Завдання
# 1. На основі документу вирішити завдання класифікації для набору даних
# Fashion MNIST.
# 2. Для моделювання використати 3 класи індекси яких взяти відповідно до
# номеру у списку групи.
# 3. Моделювання провести із використанням нейронної мережі (Flatten &amp; Dense
# layers).
# 4. Здійснити вибір оптимального кроку градієнтного алгоритму (learning_rate), а
# також побудову Confusion Matrix.
# 5. Результати оформити у вигляді файлу з кодом для моделювання та
# візуалізації у форматі .ipynb
# 6. Результати викласти у репозиторії GitHub (папка Lab4).
# 7. Підготуватися до захисту лабораторної роботи (пояснення коду, відповіді на
# запитання за темою)
# ---

# %% [markdown]
# Отримаємо дані Fashion MNIST.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['Pullover', 'Sandal', 'Ankle boot']

# %% [markdown]
# Оберемо данні 3 класів за варіантом

# %%
import numpy as np

myTrain_data = []
myTrain_labels = []
myTest_data=[]
myTest_labels  = []
for i in range(len(train_labels)):
  if (train_labels[i]==2 or train_labels[i]==5 or train_labels[i]==9 ):
    myTrain_data.append(train_data[i])
    myTrain_labels.append(train_labels[i])
for i in range(len(test_labels)):
  if (test_labels[i]==2 or test_labels[i]==5 or test_labels[i]==9 ):
    myTest_data.append(test_data[i])
    myTest_labels.append(test_labels[i])

my_train_data = np.array(myTrain_data)
my_train_labels = np.array(myTrain_labels)
my_test_data= np.array(myTest_data)
my_test_labels  = np.array(myTest_labels)

# %% [markdown]
# Виведемо декілька екземплярів наших даних.

# %%
import random
from matplotlib import pyplot as plt

plt.figure(figsize=(15, 15))
for i in range(25):
  ax = plt.subplot(5, 5, i + 1)
  rand_index = random.choice(range(len(my_train_data)))
  plt.imshow(my_train_data[i], cmap=plt.cm.binary)
  plt.title(my_train_labels[i])
  plt.axis(False)

# %% [markdown]
# Нормуємо дані.

# %%
# Divide train and test images by the maximum value (normalize it)
my_train_data = my_train_data / 255.0
my_test_data = my_test_data / 255.0

# Check the min and max values of the training data
my_train_data.min(), my_train_data.max()
# Out:
# (0.0, 0.00392156862745098)

# %% [markdown]
# Проведемо моделювання із використанням нейронної мережі (Flatten & Dense layers)

# %%
# Set random seed
tf.random.set_seed(42)

# Create the model
model_13 = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(10, activation="softmax") 
])

# Compile the model
model_13.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                 optimizer=tf.keras.optimizers.Adam(),
                 metrics=["accuracy"])

# Create the learning rate callback
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20))

# Fit the model
find_lr_history = model_13.fit(my_train_data,
                               my_train_labels,
                               epochs=40,
                               validation_data=(my_test_data, my_test_labels),
                               callbacks=[lr_scheduler])
# Out:
# Epoch 1/40
# 563/563 [==============================] - 3s 5ms/step - loss: 2.1848 - accuracy: 0.3306 - val_loss: 2.0427 - val_accuracy: 0.3333 - lr: 1.0000e-04
# Epoch 2/40
# 563/563 [==============================] - 2s 3ms/step - loss: 1.8514 - accuracy: 0.3333 - val_loss: 1.6641 - val_accuracy: 0.3333 - lr: 1.1220e-04
# Epoch 3/40
# 563/563 [==============================] - 2s 4ms/step - loss: 1.5053 - accuracy: 0.3439 - val_loss: 1.3781 - val_accuracy: 0.3333 - lr: 1.2589e-04
# Epoch 4/40
# 563/563 [==============================] - 2s 3ms/step - loss: 1.2881 - accuracy: 0.3333 - val_loss: 1.2170 - val_accuracy: 0.3333 - lr: 1.4125e-04
# Epoch 5/40
# 563/563 [==============================] - 2s 3ms/step - loss: 1.1587 - accuracy: 0.3333 - val_loss: 1.1118 - val_accuracy: 0.3333 - lr: 1.5849e-04
# Epoch 6/40
# 563/563 [==============================] - 2s 3ms/step - loss: 1.0760 - accuracy: 0.4366 - val_loss: 1.0435 - val_accuracy: 0.5820 - lr: 1.7783e-04
# Epoch 7/40
# 563/563 [==============================] - 2s 3ms/step - loss: 1.0049 - accuracy: 0.6156 - val_loss: 0.9648 - val_accuracy: 0.6447 - lr: 1.9953e-04
# Epoch 8/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.9101 - accuracy: 0.6430 - val_loss: 0.8534 - val_accuracy: 0.6473 - lr: 2.2387e-04
# Epoch 9/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.7867 - accuracy: 0.6480 - val_loss: 0.7238 - val_accuracy: 0.6517 - lr: 2.5119e-04
# Epoch 10/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.6647 - accuracy: 0.6598 - val_loss: 0.6122 - val_accuracy: 0.6643 - lr: 2.8184e-04
# Epoch 11/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.5688 - accuracy: 0.7078 - val_loss: 0.5271 - val_accuracy: 0.8073 - lr: 3.1623e-04
# Epoch 12/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.4911 - accuracy: 0.8276 - val_loss: 0.4515 - val_accuracy: 0.8500 - lr: 3.5481e-04
# Epoch 13/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.4120 - accuracy: 0.8964 - val_loss: 0.3661 - val_accuracy: 0.9253 - lr: 3.9811e-04
# Epoch 14/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.3188 - accuracy: 0.9352 - val_loss: 0.2703 - val_accuracy: 0.9460 - lr: 4.4668e-04
# Epoch 15/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.2308 - accuracy: 0.9481 - val_loss: 0.1980 - val_accuracy: 0.9493 - lr: 5.0119e-04
# Epoch 16/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.1750 - accuracy: 0.9541 - val_loss: 0.1563 - val_accuracy: 0.9530 - lr: 5.6234e-04
# Epoch 17/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.1412 - accuracy: 0.9590 - val_loss: 0.1309 - val_accuracy: 0.9570 - lr: 6.3096e-04
# Epoch 18/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.1197 - accuracy: 0.9639 - val_loss: 0.1144 - val_accuracy: 0.9613 - lr: 7.0795e-04
# Epoch 19/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.1050 - accuracy: 0.9661 - val_loss: 0.1032 - val_accuracy: 0.9647 - lr: 7.9433e-04
# Epoch 20/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0944 - accuracy: 0.9691 - val_loss: 0.0954 - val_accuracy: 0.9657 - lr: 8.9125e-04
# Epoch 21/40
# 563/563 [==============================] - 1s 3ms/step - loss: 0.0865 - accuracy: 0.9712 - val_loss: 0.0893 - val_accuracy: 0.9693 - lr: 0.0010
# Epoch 22/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0800 - accuracy: 0.9726 - val_loss: 0.0844 - val_accuracy: 0.9697 - lr: 0.0011
# Epoch 23/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0751 - accuracy: 0.9745 - val_loss: 0.0816 - val_accuracy: 0.9723 - lr: 0.0013
# Epoch 24/40
# 563/563 [==============================] - 1s 3ms/step - loss: 0.0708 - accuracy: 0.9759 - val_loss: 0.0770 - val_accuracy: 0.9740 - lr: 0.0014
# Epoch 25/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0662 - accuracy: 0.9768 - val_loss: 0.0769 - val_accuracy: 0.9737 - lr: 0.0016
# Epoch 26/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0640 - accuracy: 0.9775 - val_loss: 0.0718 - val_accuracy: 0.9743 - lr: 0.0018
# Epoch 27/40
# 563/563 [==============================] - 1s 3ms/step - loss: 0.0607 - accuracy: 0.9792 - val_loss: 0.0701 - val_accuracy: 0.9740 - lr: 0.0020
# Epoch 28/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0576 - accuracy: 0.9804 - val_loss: 0.0714 - val_accuracy: 0.9730 - lr: 0.0022
# Epoch 29/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0556 - accuracy: 0.9808 - val_loss: 0.0691 - val_accuracy: 0.9767 - lr: 0.0025
# Epoch 30/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0528 - accuracy: 0.9819 - val_loss: 0.0641 - val_accuracy: 0.9773 - lr: 0.0028
# Epoch 31/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0503 - accuracy: 0.9822 - val_loss: 0.0646 - val_accuracy: 0.9770 - lr: 0.0032
# Epoch 32/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0482 - accuracy: 0.9829 - val_loss: 0.0597 - val_accuracy: 0.9793 - lr: 0.0035
# Epoch 33/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0461 - accuracy: 0.9836 - val_loss: 0.0586 - val_accuracy: 0.9803 - lr: 0.0040
# Epoch 34/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0447 - accuracy: 0.9836 - val_loss: 0.0582 - val_accuracy: 0.9817 - lr: 0.0045
# Epoch 35/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0425 - accuracy: 0.9848 - val_loss: 0.0589 - val_accuracy: 0.9800 - lr: 0.0050
# Epoch 36/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0403 - accuracy: 0.9854 - val_loss: 0.0541 - val_accuracy: 0.9827 - lr: 0.0056
# Epoch 37/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0390 - accuracy: 0.9861 - val_loss: 0.0602 - val_accuracy: 0.9813 - lr: 0.0063
# Epoch 38/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0361 - accuracy: 0.9867 - val_loss: 0.0477 - val_accuracy: 0.9827 - lr: 0.0071
# Epoch 39/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0365 - accuracy: 0.9869 - val_loss: 0.0482 - val_accuracy: 0.9840 - lr: 0.0079
# Epoch 40/40
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0338 - accuracy: 0.9879 - val_loss: 0.0668 - val_accuracy: 0.9793 - lr: 0.0089

# %% [markdown]
# Здійснити вибір оптимального кроку градієнтного алгоритму (learning_rate)

# %%
# Plot the learning rate decay curve
import numpy as np
import matplotlib.pyplot as plt
lrs = 1e-3 * (10**(np.arange(40)/20))
plt.semilogx(lrs, find_lr_history.history["loss"]) 
plt.xlabel("Learning rate")
plt.ylabel("Loss")
plt.title("Finding the ideal learning rate");

# %% [markdown]
# Здійснемо навчання моделі з оптимальним кроком

# %%
# Set random seed
tf.random.set_seed(42)

# Create the model
model_14 = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)), 
  tf.keras.layers.Dense(3, activation="relu"),
  tf.keras.layers.Dense(3, activation="relu"),
  tf.keras.layers.Dense(10, activation="softmax") 
])

# Compile the model
model_14.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                 optimizer=tf.keras.optimizers.Adam(lr=0.01), 
                 metrics=["accuracy"])

# Fit the model
history = model_14.fit(my_train_data,
                       my_train_labels,
                       epochs=20,
                       validation_data=(my_test_data, my_test_labels))
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 563/563 [==============================] - 2s 3ms/step - loss: 0.5561 - accuracy: 0.7809 - val_loss: 0.1087 - val_accuracy: 0.9627
# Epoch 2/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0861 - accuracy: 0.9722 - val_loss: 0.0735 - val_accuracy: 0.9737
# Epoch 3/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0641 - accuracy: 0.9781 - val_loss: 0.0645 - val_accuracy: 0.9783
# Epoch 4/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0551 - accuracy: 0.9814 - val_loss: 0.0604 - val_accuracy: 0.9790
# Epoch 5/20
# 563/563 [==============================] - 1s 3ms/step - loss: 0.0485 - accuracy: 0.9831 - val_loss: 0.0555 - val_accuracy: 0.9800
# Epoch 6/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0444 - accuracy: 0.9844 - val_loss: 0.0504 - val_accuracy: 0.9817
# Epoch 7/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0411 - accuracy: 0.9861 - val_loss: 0.0540 - val_accuracy: 0.9810
# Epoch 8/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0383 - accuracy: 0.9865 - val_loss: 0.0463 - val_accuracy: 0.9823
# Epoch 9/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0367 - accuracy: 0.9869 - val_loss: 0.0488 - val_accuracy: 0.9833
# Epoch 10/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0349 - accuracy: 0.9874 - val_loss: 0.0457 - val_accuracy: 0.9817
# Epoch 11/20
# 563/563 [==============================] - 1s 3ms/step - loss: 0.0321 - accuracy: 0.9888 - val_loss: 0.0460 - val_accuracy: 0.9837
# Epoch 12/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0340 - accuracy: 0.9884 - val_loss: 0.0593 - val_accuracy: 0.9813
# Epoch 13/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0317 - accuracy: 0.9891 - val_loss: 0.0420 - val_accuracy: 0.9840
# Epoch 14/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0306 - accuracy: 0.9888 - val_loss: 0.0427 - val_accuracy: 0.9840
# Epoch 15/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0295 - accuracy: 0.9903 - val_loss: 0.0503 - val_accuracy: 0.9830
# Epoch 16/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0311 - accuracy: 0.9894 - val_loss: 0.0440 - val_accuracy: 0.9830
# Epoch 17/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0294 - accuracy: 0.9892 - val_loss: 0.0453 - val_accuracy: 0.9850
# Epoch 18/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0279 - accuracy: 0.9896 - val_loss: 0.0445 - val_accuracy: 0.9853
# Epoch 19/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0266 - accuracy: 0.9911 - val_loss: 0.0444 - val_accuracy: 0.9850
# Epoch 20/20
# 563/563 [==============================] - 2s 3ms/step - loss: 0.0279 - accuracy: 0.9903 - val_loss: 0.0454 - val_accuracy: 0.9827

# %% [markdown]
# Побудувати Confusion Matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(3, 3), text_size=15): 

  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), 
         yticks=np.arange(n_classes), 
         xticklabels=labels, 
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
             horizontalalignment="center",
             color="white" if cm[i, j] > threshold else "black",
             size=text_size)

# %%
# Make predictions with the most recent model
y_probs = model_14.predict(my_test_data)

# Convert all of the predictions from probabilities to labels
y_preds = y_probs.argmax(axis=1)

# View the first 3 prediction labels
y_preds[:3]
# Out:
# array([9, 2, 5])

# %%
# Check out the non-prettified confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true=my_test_labels, 
                 y_pred=y_preds)
# Out:
# array([[998,   0,   2],
#        [  1, 965,  34],
#        [  2,  13, 985]])

# %%
# Make a prettier confusion matrix
make_confusion_matrix(y_true=my_test_labels, 
                      y_pred=y_preds,
                      classes=class_names,
                      figsize=(15, 15),
                      text_size=10)
